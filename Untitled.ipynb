# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Örnek veri kümesi oluştur
X, _ = make_blobs(n_samples=1000, centers=4, random_state=42)

# K-Means kümeleme modelini oluştur
model = KMeans(n_clusters=4, random_state=42)

# Modeli verilere uygula
y_pred = model.fit_predict(X)

# Sonuçları görselleştir
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='viridis')
plt.show()
# Out:
# C:\Users\TARIK GULEC\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
